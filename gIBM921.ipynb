# %%
import pandas as pd
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")
df.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1  Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                            EdLevel  \
# 0  United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1    New Zealand      No  Some college/university study without earning ...
#
#                                       UndergradMajor  ...  \
# 0  Computer science, computer engineering, or sof...  ...
# 1  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# ...

# %%
df.shape
# Out:
# (11552, 85)

# %%
df[df.duplicated()].shape[0]
# Out:
# 154

# %%
df1=df['Respondent']
df1[df1.duplicated()].shape[0]
# Out:
# 154

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (11398, 85)

# %%
df[df.duplicated()].shape[0]
# Out:
# 0

# %%
df1=df['EdLevel']
print(df1.isnull().sum())
# Out:
# 112

# %%
df1=df['Country']
print(df1.isnull().sum())
# Out:
# 0

# %%
print(df.isnull().sum())
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %%
df['WorkLoc'].isnull().sum()
# Out:
# 32

# %%
df['WorkLoc'].describe()
# Out:
# count      11366
# unique         3
# top       Office
# freq        6806
# Name: WorkLoc, dtype: object

# %%
df['Employment'].describe()
# Out:
# count                  11398
# unique                     2
# top       Employed full-time
# freq                   10968
# Name: Employment, dtype: object

# %%
df1=df.groupby('UndergradMajor').nunique()
df1['Respondent'].min()
df1
# Out:
#                                                     Respondent  MainBranch  \
# UndergradMajor
# A business discipline (ex. accounting, finance,...         244           2
# A health science (ex. nursing, pharmacy, radiol...          24           2
# A humanities discipline (ex. literature, histor...         207           2
# A natural science (ex. biology, chemistry, phys...         403           2
# A social science (ex. anthropology, psychology,...         210           2
# Another engineering discipline (ex. civil, elec...         759           2
# Computer science, computer engineering, or soft...        6953           2
# Fine arts or performing arts (ex. graphic desig...         161           2
# I never declared a major                                   124           2
# Information systems, information technology, or...         794           2
# Mathematics or statistics                                  372           2
# ...

# %%
df['WorkLoc'].fillna('Office', inplace=True)
df['WorkLoc'].isnull().sum()
# Out:
# 0

# %%
df['CompFreq'].unique().tolist()
# Out:
# ['Yearly', 'Monthly', 'Weekly', nan]

# %%
df1=df.groupby('CompFreq').nunique()
df1
# Out:
#           Respondent  MainBranch  Hobbyist  OpenSourcer  OpenSource  \
# CompFreq
# Monthly         4788           2         2            4           3
# Weekly           331           2         2            4           3
# Yearly          6073           2         2            4           3
#
#           Employment  Country  Student  EdLevel  UndergradMajor  ...  \
# CompFreq                                                         ...
# Monthly            2      132        3        9              12  ...
# Weekly             2       33        3        9              12  ...
# Yearly             2       92        3        9              12  ...
#
#           WelcomeChange  SONewContent  Age  Gender  Trans  Sexuality  \
# CompFreq
# Monthly               6            15   51       7      2          6
# Weekly                5            15   40       3      2          5
# Yearly                6            15   57       7      2          7
#
# ...

# %%
df['CompFreq'].isnull().sum()
# Out:
# 206

# %%
df['CompTotal'].isnull().sum()
# Out:
# 809

# %%
df['NormalizedAnnualCompensation'] = [mult*52 if crit == 'Weekly' 
                                                  else (mult*12 if crit == 'Monthly' 
                                                        else mult) for crit, mult in zip(df['CompFreq'], df['CompTotal'])]

# %%
df[['NormalizedAnnualCompensation','CompFreq','CompTotal']]
# Out:
#        NormalizedAnnualCompensation CompFreq  CompTotal
# 0                           61000.0   Yearly    61000.0
# 1                          138000.0   Yearly   138000.0
# 2                           90000.0   Yearly    90000.0
# 3                          348000.0  Monthly    29000.0
# 4                           90000.0   Yearly    90000.0
# ...                             ...      ...        ...
# 11547                      130000.0   Yearly   130000.0
# 11548                       74400.0   Yearly    74400.0
# 11549                      105000.0   Yearly   105000.0
# 11550                       80000.0   Yearly    80000.0
# 11551                           NaN      NaN        NaN
#
# [11398 rows x 3 columns]

# %%
df['NormalizedAnnualCompensation'].median()
# Out:
# 100000.0
